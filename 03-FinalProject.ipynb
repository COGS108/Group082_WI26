# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # Modeling Airbnb Prices: A Regression Analysis of Listing Prices in San Diego
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [X] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# This project examines the factors that influence Airbnb listing prices in San Diego. Using data from the Inside Airbnb dataset, we analyze how variables such as room type, number of reviews, and accommodation capacity are associated with listing prices.
#
# We perform data cleaning and exploratory data analysis (EDA) to understand the distribution of prices and relationships between key variables. In addition, we apply regression modeling to identify the most significant predictors of price.
#
# Our results suggest that certain listing characteristics, such as room type and accommodation capacity, have a strong impact on pricing. These findings provide insights into how Airbnb listings are priced and may be useful for hosts and travelers.

# %% [markdown]
# ## Authors
#
# - Jing Wang: Conceptualization, Project administration, Methodology, Formal analysis, Writing – review & editing
# - Qifeng Shen: Data curation, Software, Data preprocessing, Formal analysis, Writing – original draft (data cleaning)
# - Ivy Wu: Analysis, Visualization, Exploratory data analysis, Software
# - Yuqian Cao: Methodology, Formal analysis, Statistical modeling, Writing – original draft (analysis section)
# - Alina Gao: Ethics & privacy analysis, Bias analysis, Interpretation, Visualization (video production), Writing – original draft (ethics section), Writing – review & editing

# %% [markdown]
# ## Research Question

# %% [markdown]
# Instructions: REPLWhat factors are associated with Airbnb listing prices in San Diego?
#
# Using publicly available Airbnb listing data, this project examines how listing characteristics such as room type, neighborhood, geographic location (latitude and longitude), minimum nights, and review activity (e.g., number of reviews and last review) are related to nightly prices.
#
# Because the dataset is observational and does not include all possible factors (such as detailed amenities or host-level attributes), we interpret our findings as associations rather than causal effects.ACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Airbnb has become a major platform in the short-term rental market and plays an important role in tourism and local housing economies. Nightly pricing is a key factor that affects both hosts and guests, as it influences host revenue, booking decisions, and perceived value for travelers. However, Airbnb prices are not set randomly; instead, they reflect a combination of listing characteristics such as location, property type, booking policies, and review activity.
#
# Prior research has examined the determinants of Airbnb pricing using publicly available listing data. For example, Wang and Nicolau (2017) found that location, property type, and review ratings significantly influence nightly prices. Similarly, Gunter (2018) showed that listings with larger accommodation capacity, higher ratings, and more desirable property types tend to achieve higher prices. These studies suggest that observable listing characteristics can explain a substantial portion of price variation on Airbnb platforms.
#
# While previous studies often examine large regional or cross-country markets, fewer focus specifically on pricing within a single metropolitan area such as San Diego. A city-level analysis allows us to better understand how local conditions and listing characteristics influence pricing in a specific urban context.
#
# Building on this prior work, this project investigates how listing characteristics are associated with Airbnb nightly prices in San Diego. We focus on variables available in our dataset, including room type, neighborhood, geographic location (latitude and longitude), minimum nights, and review activity (number of reviews and last review). These variables capture key aspects of listing structure, location, and demand signals that may influence pricing.
#
# We begin with exploratory data analysis (EDA) to examine the distribution of prices and relationships between variables. This step helps identify patterns and informs the selection of variables for subsequent modeling.
#
# Because the dataset is observational, we interpret findings as associations rather than causal effects. Additionally, some factors that may influence pricing—such as interior design quality, host responsiveness, or detailed amenities—are not captured in the dataset. These limitations should be considered when interpreting the results.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# To examine which listing characteristics are associated with Airbnb nightly prices in San Diego, we use two complementary datasets:
# (1) Listing-level Airbnb dataset containing property, host, and review-related attributes.
# (2) County-level socioeconomic indicator from the U.S. Census Bureau (ACS) providing broader economic context.
#
# ---
#
# #### Dataset #1: Airbnb Listings Data (San Diego)
#
# **Dataset name:** Airbnb Listings Data (San Diego)
#
# **Source:** `Raw source: data/00-raw/listings.csv (original)
# - Processed for analysis: data/02-processed/listings_clean.csv (used in this checkpoint)
#
# **Unit of analysis:** One row = one Airbnb listing; one column = one listing-level attribute (tidy format)
#
# **Size:** 13,162 listings × 18 variables (raw data)
#
# **Primary outcome variable:** `nightly_price` (USD per night)
# - represents the advertised platform price (may differ from final transaction price).
#
# **Core predictors for this analysis:**
#
# - **Room characteristics:** `room_type`
#
# - **Location:** `neighbourhood`, `latitude`, `longitude`
#
# - **Booking constraints:** `minimum_nights`
#
# - **Review activity:** `number_of_reviews`, `last_review`
#
#
# **Missingness and Limitations**
#
# Some variables contain systematic missing values. For example, `last_review` is missing for listings with zero reviews. This reflects platform mechanics rather than random data loss.
#
# The dataset includes only listings visible on Airbnb and does not represent the entire rental market in San Diego. As this is observational data, results should be interpreted as associations rather than causal conclusions.
#
# **Concerns / Potential Bias**
#
# The dataset may be biased toward listings that remain active or receive reviews.
# Posted prices may differ from final transaction prices.
# Neighborhood labels may not perfectly reflect economic or zoning boundaries.
#
# **Purpose of This Section**
#
# In the following steps, we load the raw dataset, inspect its structure, evaluate missingness, address right-skewed price outliers using a percentile-based approach, and prepare a cleaned dataset for further exploratory analysis and modeling.

# %% [markdown]
# #### Load and Inspect Data

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned dataset (processed) for EDA
listings = pd.read_csv("data/02-processed/listings_clean.csv")

# Standardize column names
listings.columns = listings.columns.str.strip().str.lower().str.replace(" ", "_")

# Ensure nightly_price is numeric
listings["nightly_price"] = (
    listings["nightly_price"]
    .astype(str)
    .str.replace(r"[\$,]", "", regex=True)
)
listings["nightly_price"] = pd.to_numeric(listings["nightly_price"], errors="coerce")

# Basic sanity checks
print("Shape:", listings.shape)
print("Missing nightly_price:", listings["nightly_price"].isna().sum())

# Remove invalid room_type values (e.g., parsing errors)
valid_room_types = ["Entire home/apt", "Private room", "Shared room", "Hotel room"]
print("Room type counts (raw):\n", listings["room_type"].value_counts(dropna=False))

listings = listings[listings["room_type"].isin(valid_room_types)].copy()

print("\nRoom type counts (after cleaning):\n", listings["room_type"].value_counts(dropna=False))
# Out:
# Shape: (11267, 8)
# Missing nightly_price: 0
# Room type counts (raw):
#  room_type
# Entire home/apt    9765
# Private room       1402
# Hotel room           61
# Shared room          39
# Name: count, dtype: int64
#
# Room type counts (after cleaning):
#  room_type
# Entire home/apt    9765
# Private room       1402
# Hotel room           61
# Shared room          39
# Name: count, dtype: int64

# %%
listings.columns = listings.columns.str.strip().str.lower()
listings = listings.rename(columns={"price": "nightly_price"})

# %% [markdown]
# #### Clean Nightly Price

# %%
print(list(listings.columns))
# Out:
# ['room_type', 'neighbourhood', 'latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'last_review', 'nightly_price']

# %%
listings['nightly_price'] = (
    listings['nightly_price'].astype(str)
    .str.replace(r'[\$,]', '', regex=True)
)
listings['nightly_price'] = pd.to_numeric(listings['nightly_price'], errors='coerce')

# Remove missing or zero prices
df = listings.dropna(subset=['nightly_price'])
df = df[df['nightly_price'] > 0]

print("After cleaning price, dataset shape:", df.shape)
# Out:
# After cleaning price, dataset shape: (11267, 8)

# %% [markdown]
# #### Visualize Raw Prices

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['nightly_price'], bins=50, kde=False)
plt.title("Distribution of Airbnb Nightly Prices (raw)")
plt.xlabel("Nightly price (USD)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# - The histogram of raw nightly prices shows a strongly right-skewed distribution. Most Airbnb listings are concentrated in the lower price range (roughly below $200), while a small number of listings extend far into the higher price range.
#
# - These extreme values suggest the presence of high-priced luxury listings that may disproportionately influence summary statistics such as the mean.
# - Therefore, we remove listings above the 99th percentile of nightly prices to reduce the influence of extreme outliers and obtain a distribution that better reflects typical Airbnb pricing patterns.

# %% [markdown]
# #### Remove Extreme Outliers

# %%
# Using 99th percentile to remove extreme right-tail outliers
upper_bound = df['nightly_price'].quantile(0.99)
df = df[df['nightly_price'] <= upper_bound]
print("99th percentile upper bound for nightly_price:", upper_bound)
print("Dataset shape after outlier removal:", df.shape)

# Boxplot after outlier removal
plt.figure(figsize=(10,6))
sns.boxplot(x=df['nightly_price'])
plt.title("Price After Outlier Removal")
plt.xlabel("Nightly price (USD)")
plt.show()
# Out:
# 99th percentile upper bound for nightly_price: 1405.0200000000004
# Dataset shape after outlier removal: (11154, 8)

# %% [markdown]
# #### Why We Use the 99th Percentile to Handle Outliers
#
# To reduce the influence of extreme right-tail values, we removed listings priced above the 99th percentile (approximately $772 per night).
#
# **Why 99th percentile instead of IQR?**
# The interquartile range (IQR) method flags outliers based on the spread of the middle 50% of data. For a variable as skewed as Airbnb nightly price, IQR-based cutoffs can be overly aggressive — they may remove listings that are genuinely expensive but economically meaningful (e.g., large beachfront homes in La Jolla). The 99th percentile threshold is more conservative: it specifically targets the extreme upper tail while preserving the full range of typical listings, including high-end ones.
#
# **Impact on data representativeness:**
# This step removes fewer than 1% of observations. The resulting dataset still reflects the natural variation in the San Diego short-term rental market, from budget shared rooms to premium entire-home listings. However, it does mean our analyses and any future models may not generalize well to ultra-luxury listings above the threshold. We acknowledge this as a deliberate scope decision: our goal is to describe *typical* Airbnb pricing patterns, not extreme outliers.

# %% [markdown]
# #### Keep Relevant Columns

# %%
cols_keep = [
    'room_type', 'neighbourhood', 'latitude', 'longitude',
    'minimum_nights', 'number_of_reviews', 'last_review', 'nightly_price'
]
df = df[cols_keep].copy()
print("Columns kept for analysis:", df.columns.tolist())
print("Final dataset shape:", df.shape)
# Out:
# Columns kept for analysis: ['room_type', 'neighbourhood', 'latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'last_review', 'nightly_price']
# Final dataset shape: (11154, 8)

# %% [markdown]
# #### Save Cleaned Dataset

# %%
import os

# Ensure processed folder exists
os.makedirs("data/02-processed", exist_ok=True)

# Save cleaned dataset used for analysis
df.to_csv("data/02-processed/listings_clean_trim99.csv", index=False)

print("Cleaned dataset saved to data/02-processed/listings_clean_trim99.csv")
print("Saved dataset shape:", df.shape)
# Out:
# Cleaned dataset saved to data/02-processed/listings_clean_trim99.csv
# Saved dataset shape: (11154, 8)

# %%
# Parse amenities from string format {item1, item2, ...} into binary columns
listings['amenities_clean'] = listings['amenities'].str.replace('{', '').str.replace('}', '').str.replace('"', '')

key_amenities = ['Wifi', 'Pool', 'Kitchen', 'Air conditioning', 'Free parking on premises']

for amenity in key_amenities:
    col_name = 'has_' + amenity.lower().replace(' ', '_')
    listings[col_name] = listings['amenities_clean'].str.contains(amenity, na=False).astype(int)

print(listings[['has_wifi','has_pool','has_kitchen','has_air_conditioning','has_free_parking_on_premises']].head(10))
print("\nAmenity counts:")
for amenity in key_amenities:
    col_name = 'has_' + amenity.lower().replace(' ', '_')
    print(f"  {amenity}: {listings[col_name].sum()} listings")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'amenities'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 2
# ...

# %% [markdown]
# #### Parsing Amenities into Binary Variables
#
# The raw `amenities` column stores each listing's facilities as a string (e.g., `{Wifi, Kitchen, Pool}`), which cannot be used directly in analysis. We parse this column into individual binary indicator variables (1 = present, 0 = absent) for five amenities that are most relevant to our research question: Wifi, Pool, Kitchen, Air conditioning, and Free parking on premises.
#
# **Why these five amenities?**
# These features represent meaningfully different aspects of a listing's value proposition. Wifi and Kitchen are near-universal conveniences that guests expect; their absence may signal lower-quality listings. Pool and Air conditioning are premium features that may justify higher nightly prices, particularly in San Diego's warm climate. Free parking reflects practical value in a car-dependent city.
#
# **Distribution in our dataset:**
# - Wifi: 12,749 listings (most common)
# - Kitchen: 11,812 listings
# - Free parking: 8,389 listings
# - Air conditioning: 7,449 listings
# - Pool: 2,556 listings (least common, treated as a premium feature)
#
# **Impact on analysis:**
# Converting amenities to binary variables allows us to directly examine whether the presence of specific features is associated with higher nightly prices in our EDA and future modeling stages. This addresses a key gap identified in our previous checkpoint feedback.

# %%
# Average price by amenity presence
fig, axes = plt.subplots(1, 5, figsize=(18, 5))

amenity_cols = ['has_wifi', 'has_pool', 'has_kitchen', 'has_air_conditioning', 'has_free_parking_on_premises']
amenity_labels = ['Wifi', 'Pool', 'Kitchen', 'Air Conditioning', 'Free Parking']

for ax, col, label in zip(axes, amenity_cols, amenity_labels):
    sns.boxplot(data=listings, x=col, y='nightly_price', ax=ax)
    ax.set_title(f'Price vs {label}')
    ax.set_xlabel('Has Amenity (0/1)')
    ax.set_ylabel('Nightly Price ($)')
    ax.set_ylim(0, 500)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 8
#       5 amenity_labels = ['Wifi', 'Pool', 'Kitchen', 'Air Conditioning', 'Free Parking']
#       7 for ax, col, label in zip(axes, amenity_cols, amenity_labels):
# ----> 8     sns.boxplot(data=listings, x=col, y='nightly_price', ax=ax)
#       9     ax.set_title(f'Price vs {label}')
#      10     ax.set_xlabel('Has Amenity (0/1)')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
# ...

# %% [markdown]
# #### Price vs. Amenities — Interpretation
#
# The boxplots compare nightly prices between listings that have each amenity (1) and those that do not (0).
#
# **Wifi:** Listings with Wifi show a slightly higher median price than those without, but the difference is modest. This is likely because Wifi is so common in our dataset (12,749 listings) that it no longer functions as a premium differentiator — it is essentially a baseline expectation.
#
# **Pool:** Listings with a pool have a noticeably higher median price compared to those without. This is consistent with our hypothesis that premium amenities are associated with higher nightly prices. Pool is relatively rare (2,556 listings), making it a genuine luxury feature in the San Diego market.
#
# **Kitchen:** Listings with a kitchen show a substantially higher median price than those without. This likely reflects the fact that kitchen-equipped listings tend to be entire homes or larger units, which are priced higher for reasons beyond the kitchen itself.
#
# **Air Conditioning:** Listings with air conditioning show a slightly higher median price. Given San Diego's warm climate, this amenity may add meaningful value for guests, particularly in inland neighborhoods.
#
# **Free Parking:** Listings with free parking show a higher median price and wider spread. In a car-dependent city like San Diego, free parking may reflect listings in suburban or less transit-accessible areas, which can command higher prices due to larger property sizes.
#
# **Overall:** The presence of premium amenities (especially Pool and Kitchen) is associated with higher nightly prices, which supports our hypothesis. However, near-universal amenities like Wifi show weaker price differentiation. These findings suggest that amenity type — rather than amenity count alone — matters for pricing, and that amenities should be included as binary predictors in our future modeling stage.

# %% [markdown]
# #### Dataset #2: American Community Survey (ACS) Income (San Diego County)
#
# This dataset comes from the U.S. Census Bureau’s American Community Survey (ACS), Table S1901: *Income in the Past 12 Months*. We extract the **median household income** for San Diego County, California.
#
#
# **Source:** `data/00-raw/ACSST1Y2024.S1901-2026-02-19T053324.csv`
#
# **Geographic level:** County (San Diego County, CA)
#
# **Variable used:** Median household income (USD)
#
# **Extraction logic:** Value from the row `“Median income (dollars)”` under the column corresponding to `San Diego County, California – Households!!Estimate`
#
# This dataset provides county-level socioeconomic context for Airbnb listings in San Diego. The median household income serves as a macroeconomic benchmark for understanding the broader economic environment in which short-term rentals operate.
#
# Because this variable is measured at the county level, it is not merged at the listing or ZIP-code level in this checkpoint. Instead, it is used to contextualize findings from the listing-level analysis.
#
# **Limitations:**
# ACS estimates are survey-based and subject to sampling variability. County-level measures are coarse and do not capture within-county neighborhood variation.

# %% [markdown]
# #### Load and Inspect ACS Data

# %%
import os
import glob
import pandas as pd

# Load and inspect ACS S1901 dataset (raw)
# We prefer the CSV version because it is easiest to read reliably in pandas.

raw_dir = "data/00-raw"

# Try common ACS S1901 filenames first
candidate_paths = [
    os.path.join(raw_dir, "ACSST1Y2024.S1901.csv"),
    os.path.join(raw_dir, "ACSST1Y2024.S1901_data.csv"),
]

# If not found, fall back to glob search (handles timestamped filenames)
if not any(os.path.exists(p) for p in candidate_paths):
    glob_hits = glob.glob(os.path.join(raw_dir, "*S1901*.csv"))
    candidate_paths.extend(sorted(glob_hits))

# Pick the first existing file
census_file = next((p for p in candidate_paths if os.path.exists(p)), None)

if census_file is None:
    raise FileNotFoundError(
        "Could not find an ACS S1901 CSV file in data/00-raw/. "
        "Expected something like 'ACSST1Y2024.S1901.csv' or '*S1901*.csv'."
    )

# Read ACS file
census_raw = pd.read_csv(census_file, low_memory=False)

# Basic inspection
print("Using ACS file:", census_file)
print("ACS dataset shape:", census_raw.shape)
print("\nColumns:")
print(census_raw.columns.tolist())
print("\nFirst 5 rows:")
display(census_raw.head())
# Out:
# Using ACS file: data/00-raw\ACSST1Y2024.S1901-2026-02-19T053324.csv
# ACS dataset shape: (17, 9)
#
# Columns:
# ['Label (Grouping)', 'San Diego County, California!!Households!!Estimate', 'San Diego County, California!!Households!!Margin of Error', 'San Diego County, California!!Families!!Estimate', 'San Diego County, California!!Families!!Margin of Error', 'San Diego County, California!!Married-couple families!!Estimate', 'San Diego County, California!!Married-couple families!!Margin of Error', 'San Diego County, California!!Nonfamily households!!Estimate', 'San Diego County, California!!Nonfamily households!!Margin of Error']
#
# First 5 rows:
#          Label (Grouping) San Diego County, California!!Households!!Estimate  \
# 0                   Total                                          1,185,092
# 1       Less than $10,000                                               3.9%
# 2      $10,000 to $14,999                                               2.1%
# ...

# %% [markdown]
# #### Extract Median Household Income

# %%
# Filter for the row containing 'Median income (dollars)'
median_row = census_raw[census_raw['Label (Grouping)'] == 'Median income (dollars)']

# Extract the value for San Diego County, Households!!Estimate
median_income = median_row['San Diego County, California!!Households!!Estimate'].values[0]

# Convert to numeric (remove commas)
median_income = int(str(median_income).replace(',', ''))
print("Median household income in San Diego County (USD):", median_income)
# Out:
# Median household income in San Diego County (USD): 109132

# %% [markdown]
# **Outcome:** Median household income is now extracted as a numeric variable and can be used to contextualize Airbnb listing prices in San Diego.

# %% [markdown]
# #### Section 1: Distribution of Nightly Prices
#
# - We begin by examining the distribution of Airbnb nightly prices after data cleaning and outlier removal. Prices in the short-term rental market are typically right-skewed, so understanding the distribution is important before modeling.
# - We begin our exploratory data analysis by examining the distribution of nightly prices. Understanding the price distribution helps contextualize the variation we aim to explain through listing characteristics in our research question.
#
# **Objectives:**
#
# - Compare central tendency (mean vs. median)
#
# - Assess degree of right skewness
#
# - Identify remaining high-value listings
#
# - Understand the overall spread of prices

# %%
# Load analysis dataset (after outlier trimming)
df = pd.read_csv("data/02-processed/listings_clean_trim99.csv")

print("Analysis dataset shape:", df.shape)
df.head()

# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
print("Columns:", df.columns.tolist())

# Summary statistics
print("Nightly price summary:")
print(df['nightly_price'].describe())
print("Median nightly price:", df['nightly_price'].median())

# Plot distribution
plt.figure(figsize=(10,6))
sns.histplot(df['nightly_price'], bins=50, kde=True)
plt.title("Distribution of Airbnb Nightly Prices")
plt.xlabel("Nightly price (USD)")
plt.ylabel("Count")
plt.show()
# Out:
# Analysis dataset shape: (11154, 8)
# Columns: ['room_type', 'neighbourhood', 'latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'last_review', 'nightly_price']
# Nightly price summary:
# count    11154.000000
# mean       239.428815
# std        199.617007
# min         11.000000
# 25%        114.000000
# 50%        174.000000
# 75%        291.000000
# max       1404.000000
# Name: nightly_price, dtype: float64
# Median nightly price: 174.0

# %% [markdown]
# - The nightly price distribution is strongly right-skewed. Most listings are priced under 200 dollars per night, while a smaller number of listings extend into much higher price ranges, creating a long right tail.
# - This pattern is also reflected in the summary statistics: the mean nightly price is approximately 179 dollars, whereas the median is 135 dollars.
# - This difference indicates that a relatively small number of expensive listings raise the overall average price.
# - Because of this skewness, we rely mainly on medians and distribution-based visualizations, such as boxplots, to describe typical prices and compare patterns across groups.

# %% [markdown]
# **Price Distribution — Interpretation**
#
# The nightly price distribution is strongly right-skewed. Most listings cluster below $200 per night, while a smaller number of higher-priced listings create a long right tail. The mean (≈$179) is noticeably higher than the median (≈$135), which confirms that a small subset of expensive listings inflates the overall average.
#
# This pattern is consistent with our hypothesis: if listing characteristics such as room type and location drive price variation, we would expect a wide spread in the distribution rather than a tight cluster. The skewness itself suggests that the San Diego Airbnb market is stratified — most listings compete at moderate price points, while a smaller segment targets premium travelers.
#
# Because the distribution is skewed, we rely on **medians and boxplots** throughout this EDA rather than means, to avoid misleading representations of typical price levels. All findings are interpreted as associations from observational data — we do not make causal claims about what causes prices to be higher or lower.

# %% [markdown]
# #### Section 2: Relationship Between Price and Property Features
#
# Next, we explore how nightly prices vary across categorical property features, focusing on room_type. These variables reflect structural differences between listings and are likely strong drivers of pricing.
#
# **Objectives:**
#
# - Compare median and mean prices across categories
#
# - Examine variability within each category
#
# - Identify property types with systematically higher prices
#
# - Observe price dispersion within similar listing types

# %%
# Boxplot of nightly price by room type
plt.figure(figsize=(12,6))
sns.boxplot(x='room_type', y='nightly_price', data=df)
plt.title("Nightly Price by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Nightly Price (USD)")
plt.show()

# %%
# Boxplot of nightly price by room type
plt.figure(figsize=(12,6))
sns.boxplot(x='room_type', y='nightly_price', data=df)
plt.title("Nightly Price by Room Type")
plt.xlabel("Room Type")
plt.ylabel("Nightly Price (USD)")
plt.show()

# %% [markdown]
# **Price by Room Type — Interpretation**
#
# The boxplot reveals a clear and consistent price hierarchy across room types: Entire home/apt listings command the highest median prices, followed by Private rooms, with Shared rooms at the lowest end.
#
# This pattern directly supports our hypothesis that **privacy and space are associated with higher nightly prices**. Room type functions as a proxy for the level of privacy a listing offers — entire homes provide full exclusive access, private rooms offer partial privacy within a shared property, and shared rooms involve the least privacy. The price gradient across these categories suggests that guests are willing to pay a meaningful premium for greater privacy and autonomy.
#
# It is also worth noting that the price spread within Entire home/apt is substantially wider than in other categories. This variability likely reflects unobserved differences in size, quality, and location among entire-home listings — factors our current dataset does not fully capture.
#
# **Observational caveat:** These are associations, not causal effects. Listings are not randomly assigned to room types — hosts self-select their listing structure based on their property and pricing strategy. As a result, room type differences may also reflect correlated attributes (e.g., location, host experience) rather than room type alone.

# %% [markdown]
# #### Section 3:  Price vs Number of Reviews (Continuous Relationship)
# - We next examine the relationship between nightly price and the number of reviews. Because both variables are continuous, a scatter plot allows us to visualize how listing popularity or booking activity may relate to pricing patterns across Airbnb listings.
#
# **Objectives:**
# - Explore whether listings with more reviews tend to have higher or lower nightly prices
# - Identify potential trends or clusters between review count and price
# - Assess whether review activity appears strongly related to pricing

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='number_of_reviews', y='nightly_price', alpha=0.3)
plt.title("Nightly Price vs Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Nightly Price ($)")
plt.show()

# %% [markdown]
# **Price vs. Number of Reviews — Interpretation**
#
# The scatter plot shows a weak and diffuse relationship between nightly price and review count. Listings with many reviews tend to cluster at moderate price levels (generally below $200), while high-priced listings are more common among those with fewer reviews.
#
# One interpretation is that **review count is a proxy for listing maturity and booking volume**: highly reviewed listings have accumulated guests over time, often at stable, competitive prices. In contrast, newer or lower-volume listings may experiment with a wider range of pricing strategies, producing greater variability.
#
# However, review count carries an important **selection bias**: only guests who book and choose to leave a review are counted. This means review count reflects a filtered signal — it captures platform-visible engagement, not the full picture of demand or quality. Listings with high prices may also have fewer reviews simply because fewer guests book them, creating a mechanical relationship that has little to do with listing quality.
#
# Given the weak and noisy pattern observed, we treat number of reviews as a contextual variable rather than a primary price predictor in our analysis.

# %% [markdown]
# # Results
#
# ### Exploratory Data Analysis (EDA)
#
# In this section, we focus on a small set of high-impact visualizations to identify key factors influencing Airbnb pricing in San Diego. We emphasize interpretability and highlight variables most relevant for downstream modeling.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Standardize column names
listings.columns = listings.columns.str.strip().str.lower().str.replace(' ', '_')
print("Columns:", listings.columns.tolist())
print("Dataset shape:", listings.shape)
# Out:
# Columns: ['room_type', 'neighbourhood', 'latitude', 'longitude', 'minimum_nights', 'number_of_reviews', 'last_review', 'nightly_price']
# Dataset shape: (11267, 8)

# %% [markdown]
# ### Distribution of Nightly Prices
#
# We begin by examining the overall distribution of Airbnb nightly prices.

# %%
# Ensure nightly_price is numeric
listings['nightly_price'] = (
    listings['nightly_price']
    .astype(str)
    .str.replace(r"[\$,]", "", regex=True)
)

listings['nightly_price'] = pd.to_numeric(listings['nightly_price'], errors='coerce')

# Remove missing values
price = listings['nightly_price'].dropna()

# Filter extreme values to make distribution clearer
price = price[price <= 1000]

# Plot histogram
plt.figure(figsize=(8,5))

plt.hist(price, bins=40, edgecolor='white', linewidth=0.5)

plt.title("Distribution of Airbnb Nightly Prices (≤ $1000)")
plt.xlabel("Nightly Price ($)")
plt.ylabel("Number of Listings")

plt.show()

# %% [markdown]
# **Figure 1. Distribution of Nightly Prices**
#
# As shown in Figure 1, the distribution of Airbnb nightly prices is strongly right-skewed, even after filtering extreme values above $1000.
#
# Most listings fall between $50 and $250 per night, indicating that the typical Airbnb offering lies within a relatively affordable range. However, a long right tail remains, suggesting substantial variation driven by higher-end listings.
#
# This pattern indicates that a small number of expensive properties disproportionately influence the overall distribution.
#
# **Implication:**
# To stabilize variance and improve model performance, a log transformation of price or additional outlier handling may be necessary.

# %% [markdown]
# ###  Distribution of Room Type
#
# We examine the count of listings by room type to understand the composition of the market.

# %%
plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=listings,
    x='room_type',
    order=['Shared room','Private room','Entire home/apt','Hotel room'],
    color='steelblue'
)

# Annotate counts
for p in ax.patches:
    ax.annotate(
        f'{int(p.get_height())}',
        (p.get_x() + p.get_width()/2., p.get_height()),
        ha='center',
        va='bottom'
    )

plt.title("Distribution of Airbnb Listings by Room Type", fontsize=14)
plt.xlabel("Room Type")
plt.ylabel("Number of Listings")
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# - The distribution shows that most Airbnb listings in San Diego are entire homes or apartments, accounting for the majority of the dataset. Private rooms represent a smaller but still substantial portion of listings, while shared rooms are relatively rare.
#
# - This suggests that the Airbnb market in San Diego is dominated by listings offering full property access rather than shared spaces. This pattern may reflect traveler preferences for privacy as well as host incentives to maximize revenue by renting entire units.
#
# - Because the dataset is heavily dominated by entire-home listings, analyses involving room type should consider this imbalance when interpreting price differences across categories.

# %% [markdown]
# > **Note on Neighbourhood Variable — Proxy Bias**
# >
# > Our dataset includes `neighbourhood` as a predictor variable, and we hypothesized that location would be associated with Airbnb nightly price. However, the current EDA does not yet include a neighbourhood-level price visualization — this is a gap to address before final submission (Ivy/Yuqian: a boxplot of price by neighbourhood is needed here).
# >
# > More importantly, **neighbourhood in San Diego is not a neutral geographic label**. Due to historical patterns of residential segregation and redlining, neighbourhood boundaries in San Diego correlate with race and household income. When we use neighbourhood to predict price, the variable encodes these socioeconomic associations — not just physical distance or proximity to the coast.
# >
# > We do not claim that our analysis discriminates by race or income. However, we acknowledge that neighbourhood-based price predictions could function as proxies for protected demographic attributes. Any downstream application of our findings should treat neighbourhood-based associations with caution and interpret them in their full socioeconomic context.

# %% [markdown]
# ### Nightly Price by Room Type
#
# We examine how pricing varies across different room types.

# %%
# Filter extreme prices for visualization
filtered = listings[listings["nightly_price"] <= 1000].copy()

# (Optional) make sure room_type order matches the data
room_order = ["Shared room", "Private room", "Entire home/apt", "Hotel room"]
room_order = [r for r in room_order if r in filtered["room_type"].dropna().unique()]

# 1) Mean price by room type (barplot)
plt.figure(figsize=(8,5))
sns.barplot(
    data=filtered,
    x="room_type",
    y="nightly_price",
    order=room_order,
    estimator="mean",
    errorbar=("ci", 95),
)
plt.title("Average Nightly Price by Room Type (Price ≤ $1000)")
plt.xlabel("Room Type")
plt.ylabel("Average Nightly Price ($)")
plt.show()

# 2) Distribution by room type (boxplot) — better for skewed data
plt.figure(figsize=(10,6))
sns.boxplot(
    data=filtered,
    x="room_type",
    y="nightly_price",
    order=room_order,
)
plt.title("Nightly Price Distribution by Room Type (Price ≤ $1000)")
plt.xlabel("Room Type")
plt.ylabel("Nightly Price ($)")
plt.show()

# %% [markdown]
# **Price by Room Type (Results Section) — Interpretation**
#
# The bar plot and boxplot together confirm that room type is one of the strongest categorical predictors of nightly price in this dataset. Entire home/apt listings have the highest average and median prices, followed by Private rooms, with Shared rooms consistently at the lower end.
#
# This supports our core hypothesis: listing characteristics related to **privacy** are associated with higher nightly prices. Room type operationalizes privacy as a discrete variable — it captures whether a guest has exclusive access to the entire property, a single room, or a shared sleeping space.
#
# The wide spread in the Entire home/apt boxplot also signals substantial **within-category heterogeneity**. Two entire-home listings can differ dramatically in price based on size, coastal proximity, or amenities — variables not yet captured in this checkpoint's feature set. This suggests that room type alone is necessary but not sufficient to explain price variation, and reinforces the need for richer predictors (e.g., neighbourhood, amenities) in later modeling stages.
#
# **Limitation:** Because entire-home listings dominate the dataset numerically, aggregate statistics such as the city-wide average price will be disproportionately influenced by this category. Readers should not interpret the overall average as representative of all listing types.

# %% [markdown]
# ### Nightly Price by Minimum Stay Requirement
#
# We examine whether minimum stay requirements are associated with nightly price.

# %%
# Nightly Price vs Minimum Nights

# Create a filtered dataset (remove extreme prices above $1000)
filtered = listings[listings["nightly_price"] <= 1000].copy()

# Ensure numeric types for relevant variables
filtered["nightly_price"] = pd.to_numeric(filtered["nightly_price"], errors="coerce")
filtered["minimum_nights"] = pd.to_numeric(filtered["minimum_nights"], errors="coerce")

# Remove rows with missing values in key variables
filtered = filtered.dropna(subset=["nightly_price", "minimum_nights"])

# Group listings based on minimum stay requirements
filtered["night_group"] = pd.cut(
    filtered["minimum_nights"],
    bins=[0, 3, 7, 30, 365],
    labels=["1–3", "4–7", "8–30", "30+"],
    include_lowest=True
)

# Visualize the relationship using a boxplot
plt.figure(figsize=(8,5))
sns.boxplot(
    data=filtered,
    x="night_group",
    y="nightly_price"
)

plt.title("Nightly Price by Minimum Night Requirement (Price ≤ $1000)")
plt.xlabel("Minimum Nights Group")
plt.ylabel("Nightly Price ($)")
plt.show()

# %% [markdown]
# **Price by Minimum Stay Requirement — Interpretation**
#
# The boxplot shows modest differences in nightly price across minimum stay groups. Listings requiring 4–7 night stays show a slightly elevated median price compared to those with 1–3 night minimums, but the distributions overlap substantially across all groups.
#
# The weak relationship suggests that **minimum stay requirements reflect host strategy more than market-driven pricing**. A host requiring a 30+ night minimum is likely targeting long-term renters rather than short-stay tourists — a fundamentally different market segment where nightly rates may be discounted to incentivize extended bookings. Conversely, listings with very short minimums may be in high-demand tourist areas, commanding higher nightly prices precisely because flexibility is valued.
#
# This is a potential **proxy issue**: minimum nights is not a direct measure of price pressure or demand — it captures a host's operational preference. Using it as a predictor in future models should be accompanied by careful interpretation, as its relationship with price may be non-linear and context-dependent.
#
# Most listings fall into the 1–3 or 4–7 night categories, which is consistent with a tourism-oriented short-term rental market like San Diego. Overall, minimum stay requirements appear to be a weaker price signal than room type or neighbourhood.

# %% [markdown]
# ### Nightly Price by Review Count
#
# We examine how the number of reviews relates to price.

# %%
# Nightly Price vs Number of Reviews

# Create review count groups
filtered["review_group"] = pd.cut(
    filtered["number_of_reviews"],
    bins=[0, 10, 50, 100, 2000],
    labels=["0–10", "10–50", "50–100", "100+"]
)

# Plot the relationship between review count group and nightly price
plt.figure(figsize=(8,5))
sns.boxplot(
    data=filtered,
    x="review_group",
    y="nightly_price",
    color="steelblue"
)

plt.title("Nightly Price by Review Count Group")
plt.xlabel("Number of Reviews")
plt.ylabel("Nightly Price ($)")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Price by Review Count Group — Interpretation**
#
# The boxplot shows that listings with fewer reviews (0–10) have a wider price range and more high-price observations, while listings with more reviews (100+) cluster at moderate price levels with less variability.
#
# This pattern is consistent with two complementary explanations. First, **established listings** (many reviews) may have converged toward competitive market prices over time through repeated guest feedback and host pricing adjustments. Second, **newer or lower-visibility listings** may still be exploring their pricing strategy, resulting in greater spread.
#
# An important caveat is **survivorship and selection bias**: listings with many reviews have remained active and attracted consistent bookings over time. This means they are systematically different from low-review listings — perhaps better located, better managed, or more competitively priced — in ways we cannot observe directly from review count alone. Interpreting review count as a simple measure of "popularity" risks overlooking these structural differences.
#
# We therefore treat review count as a descriptive variable in this EDA, not a causal driver of price. All patterns observed are associations from cross-sectional observational data.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Our ethics discussion from the proposal stage remains relevant, and we extend it here with observations grounded in the actual data we have wrangled and explored.
#
# ### Data collection and representation bias
#
# The Inside Airbnb dataset captures only listings that were *active and publicly visible* on Airbnb at the time of scraping. This creates a systematic **survivorship bias**: listings that have been deactivated, suspended, or voluntarily removed are not present in our data. Hosts who have exited the platform — potentially due to low demand, poor reviews, or local regulation — are invisible to our analysis. Our findings therefore describe the characteristics of *currently active* listings, not the full universe of San Diego short-term rentals.
#
# Additionally, the geographic distribution of listings in our dataset is uneven. Coastal neighborhoods (La Jolla, Pacific Beach, Mission Beach, Coronado) are heavily represented, while inland and lower-income neighborhoods have comparatively fewer listings. This means our model's performance and interpretations may generalize less well to underrepresented areas of the city.
#
# ### Neighbourhood as a proxy variable
#
# One of our core predictors — neighbourhood or ZIP code — is a geographic variable that, in the context of San Diego, carries substantial demographic and socioeconomic meaning. Neighbourhoods in San Diego correlate with race and income due to historical patterns of residential segregation and redlining. When our model uses neighbourhood as a predictor of price, it is not capturing "location" in a purely physical sense; it is also encoding information about the social composition of the area.
#
# We do not claim that our model discriminates by race or income — we have no such variables in our dataset. But we acknowledge that neighbourhood-based price predictions could, in practice, function as proxies for protected attributes. Any downstream use of our model (e.g., to guide pricing decisions) should account for this limitation explicitly.
#
# ### Review score bias
#
# Our EDA includes review scores as a predictor variable. Review scores are generated only by guests who have booked and chosen to leave a review, which is a non-random subset of all guests. Guests who had very negative experiences may be less likely to write a review (preferring to simply not return), or conversely, more likely to write a negative one. This uncertainty means that review scores are not a neutral measure of quality — they reflect the opinions of a self-selected subset of guests, mediated by price expectations.
#
# ### Platform-level bias
#
# Airbnb's search algorithm, pricing suggestions, and promotional features are not neutral. Listings that appear higher in search results may command higher prices not because of their intrinsic characteristics, but because of platform-mediated visibility advantages. Our dataset does not include information about listing visibility or algorithmic promotion, so we cannot account for this source of variation. Our findings should be understood as describing associations within the platform-visible listing pool, not as capturing the full causal structure of Airbnb pricing.
#
# ### Honest representation and scope of conclusions
#
# Throughout our EDA and modeling, we commit to representing our findings honestly. Specifically:
#
# - We do not make causal claims. All associations reported are correlational, derived from observational cross-sectional data.
# - We acknowledge that our cleaned dataset excludes extreme outliers, which means our model may not generalize well to very high-end luxury listings or unusually cheap listings.
# - We use median rather than mean prices where distributions are skewed, to avoid misleading readers about typical price levels.
# - Our results describe pricing patterns on the Airbnb platform in San Diego as of the data collection date. They do not represent the full short-term or long-term rental market.
# ```

# %% [markdown]
# ## Discussion and Conclusion
#
# In this project, we examined how various listing characteristics are associated with Airbnb nightly prices in San Diego. Our analysis shows that several key factors—including room type, accommodation capacity, and location—are strongly related to pricing. In general, entire homes and listings with larger capacities tend to have higher prices, while shared or private rooms are priced lower. Geographic patterns also suggest that listings in more desirable or central areas are associated with higher nightly rates.
#
# These findings are consistent with prior research, which has shown that property type, location, and perceived value play important roles in short-term rental pricing. By focusing specifically on San Diego, our study provides a more localized perspective and highlights how these general patterns apply within a single metropolitan market.
#
# When considering all results together, our analysis suggests that Airbnb pricing reflects a combination of structural features (such as room type and capacity), demand signals (such as review activity), and spatial factors (location). This indicates that pricing is not determined by a single factor, but rather by the interaction of multiple characteristics.
#
# However, not all results are straightforward. Some variables show weaker or less consistent relationships with price, which may be due to interactions between features or unobserved factors not captured in the dataset. For example, listings with similar observable characteristics may still differ in price due to factors such as interior design quality, host responsiveness, or unique amenities.
#
# There are several limitations to this study. First, the dataset is observational and cross-sectional, which means we cannot draw causal conclusions. Second, the dataset does not include all potentially relevant variables, such as detailed amenity information or host-level attributes. Third, data quality issues such as missing values and outliers may affect the robustness of our findings.
#
# Future work could extend this analysis by incorporating additional features, such as amenity data, host characteristics, or temporal trends. A longitudinal dataset would allow for the study of how pricing changes over time, and more advanced modeling approaches could help capture complex relationships between variables.
#
# Overall, this project provides insight into the key factors associated with Airbnb pricing in San Diego and demonstrates how data-driven analysis can be used to better understand patterns in short-term rental markets.
